# %%
# !git clone https://github.com/IBM-EPBL/IBM-Project-321-1658278283.git
# Out:
# Cloning into 'IBM-Project-321-1658278283'...
# remote: Enumerating objects: 19284, done.
# remote: Counting objects: 100% (1368/1368), done.
# remote: Compressing objects: 100% (983/983), done.
# remote: Total 19284 (delta 504), reused 1169 (delta 385), pack-reused 17916
# Receiving objects: 100% (19284/19284), 15.44 MiB | 27.45 MiB/s, done.
# Resolving deltas: 100% (1197/1197), done.

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 6.5 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 53.6 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 11.5 MB/s
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train = train_datagen.flow_from_directory('/content/IBM-Project-321-1658278283/Data Collection',target_size=(64,64),batch_size=300,class_mode='categorical',color_mode="grayscale")
# Out:
# Found 16978 images belonging to 2 classes.

# %%
x_test = test_datagen.flow_from_directory('/content/IBM-Project-321-1658278283/Data Collection',target_size=(64,64),batch_size=300,class_mode='categorical',color_mode="grayscale")
# Out:
# Found 16978 images belonging to 2 classes.
